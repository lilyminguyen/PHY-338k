# %% [markdown]
# # Analysis

# %% [markdown]
# fitting sine wave output to sine function (not FFT THD)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("11-21.CSV", skiprows=15)
print(df.head())
# Out:
#        TIME   CH1
# 0 -0.032000  0.38
# 1 -0.031997  0.38
# 2 -0.031994  0.38
# 3 -0.031990  0.38
# 4 -0.031987  0.38
