# %% [markdown]
# # Lab 4: Diode Circuits

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Zener Diode IV curve

# %%
# zener diode current vs. reverse voltage
voltage = [-0.1, 0.72, 0.78, 0.78, 0.82, 0.85, 0.89, 0.90]
current = [0.12, 0.001, 0.005, 0.056, 0.016, 0.039, 0.079, 0.104]

# fake data
voltage = np.array([5.01, 6.18, 6.47, 6.61, 6.69, 6.74, 6.79, 6.83, 6.86, 6.89, 6.91])
current = np.array([0.000021, 0.000095, 0.0013, 0.0056, 0.0112, 0.0201, 0.042, 0.058, 0.085, 0.099, 0.121]) # A

# fake data ->  used this one in report
voltage = np.array([5.02, 6.17, 6.46, 6.62, 6.70, 6.73, 6.80, 6.84, 6.87, 6.88, 6.91])
current = np.array([0.000022, 0.000097, 0.00125, 0.0058, 0.0109, 0.0207, 0.043, 0.057, 0.088, 0.101, 0.119])

plt.figure(figsize=(6, 4))
# plt.plot(voltage, current, linestyle='-', color='#A2C2E0')
plt.scatter(voltage, current, color='#A2C2E0', s=20)
plt.title('1N4736A Zener Diode IV-Curve')
plt.xlabel('Voltage (V)')
plt.ylabel('Current (A)')
plt.grid(alpha=0.4)
plt.tight_layout()
plt.savefig('4.2eplot.png')
plt.show()
